# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("eda_dataset.csv")

# %%
print(df.head())
# Out:
#    customer_id  age       city     category  purchase_amount  rating  discount
# 0            1   22  Bangalore  Electronics          3424.70     2.4     28.20
# 1            2   43     Mumbai       Sports           108.36     2.2     36.51
# 2            3   55      Delhi       Sports          4220.33     2.0     36.88
# 3            4   20  Bangalore       Sports          3843.78     3.3     26.90
# 4            5   51     Mumbai     Clothing          4092.09     4.5     35.96

# %%
# null values
print(df.isnull().sum())

# drop nulls (if any)
df = df.dropna()

# remove duplicates
df = df.drop_duplicates()
# Out:
# customer_id        0
# age                0
# city               0
# category           0
# purchase_amount    0
# rating             0
# discount           0
# dtype: int64

# %% [markdown]
# **🔥EDA🔥**

# %% [markdown]
# SHAPE

# %%
print(df.shape)
# Out:
# (3000, 7)

# %% [markdown]
# DATA TYPES

# %%
print(df.dtypes)
# Out:
# customer_id          int64
# age                  int64
# city                object
# category            object
# purchase_amount    float64
# rating             float64
# discount           float64
# dtype: object

# %% [markdown]
# SUMMARY STATISTICS

# %%
print(df.describe())
# Out:
#        customer_id         age  purchase_amount       rating     discount
# count  3000.000000  3000.00000      3000.000000  3000.000000  3000.000000
# mean   1500.500000    38.80000      2551.703577     3.007900    25.341550
# std     866.169729    12.36561      1420.767417     1.161604    14.246874
# min       1.000000    18.00000       100.030000     1.000000     0.000000
# 25%     750.750000    28.00000      1326.820000     2.000000    12.910000
# 50%    1500.500000    39.00000      2554.695000     3.000000    25.915000
# 75%    2250.250000    49.00000      3795.912500     4.000000    37.522500
# max    3000.000000    60.00000      4998.570000     5.000000    49.990000

# %% [markdown]
# **VISUALISATION**

# %% [markdown]
# Histogram(distribution)

# %%
plt.hist(df['purchase_amount'])
plt.title("Purchase Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Box plot (Outliers)

# %%
sns.boxplot(x=df['purchase_amount'])
plt.title("Boxplot of Purchase Amount")
plt.show()

# %% [markdown]
# Heatmap (Correlation)

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()
